# %%
# !pip3 install --upgrade google-api-python-client google-auth-httplib2 google-auth-oauthlib
# !pip3 install gspread oauth2client
# !pip3 install requests
# !pip3 install langchain
# !pip3 install openai
# !pip3 install gspread oauth2client google-auth google-auth-oauthlib google-auth-httplib2 google-api-python-client
# !pip3 install python-dotenv
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting google-api-python-client
#   Downloading google_api_python_client-2.90.0-py2.py3-none-any.whl (11.4 MB)
#      |████████████████████████████████| 11.4 MB 2.3 MB/s eta 0:00:01
# Collecting google-auth-httplib2
#   Downloading google_auth_httplib2-0.1.0-py2.py3-none-any.whl (9.3 kB)
# Collecting google-auth-oauthlib
#   Downloading google_auth_oauthlib-1.0.0-py2.py3-none-any.whl (18 kB)
# Collecting google-auth<3.0.0.dev0,>=1.19.0
#   Downloading google_auth-2.21.0-py2.py3-none-any.whl (182 kB)
#      |████████████████████████████████| 182 kB 16.7 MB/s eta 0:00:01
# Collecting uritemplate<5,>=3.0.1
#   Downloading uritemplate-4.1.1-py2.py3-none-any.whl (10 kB)
# Collecting httplib2<1.dev0,>=0.15.0
#   Downloading httplib2-0.22.0-py3-none-any.whl (96 kB)
#      |████████████████████████████████| 96 kB 14.6 MB/s eta 0:00:01
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5
#   Downloading google_api_core-2.11.1-py3-none-any.whl (120 kB)
#      |████████████████████████████████| 120 kB 22.1 MB/s eta 0:00:01
# Requirement already satisfied: six in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from google-auth-httplib2) (1.15.0)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Collecting googleapis-common-protos<2.0.dev0,>=1.56.2
#   Downloading googleapis_common_protos-1.59.1-py2.py3-none-any.whl (224 kB)
#      |████████████████████████████████| 224 kB 25.9 MB/s eta 0:00:01
# Collecting requests<3.0.0.dev0,>=2.18.0
#   Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 7.3 MB/s  eta 0:00:01
# Collecting protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5
#   Downloading protobuf-4.23.3-cp37-abi3-macosx_10_9_universal2.whl (400 kB)
#      |████████████████████████████████| 400 kB 20.3 MB/s eta 0:00:01
# Collecting urllib3<2.0
#   Downloading urllib3-1.26.16-py2.py3-none-any.whl (143 kB)
#      |████████████████████████████████| 143 kB 27.4 MB/s eta 0:00:01
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.3.0-py2.py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 18.4 MB/s eta 0:00:01
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.3.1-py3-none-any.whl (9.3 kB)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2
#   Downloading pyparsing-3.1.0-py3-none-any.whl (102 kB)
#      |████████████████████████████████| 102 kB 19.8 MB/s eta 0:00:01
# Collecting pyasn1<0.6.0,>=0.4.6
#   Downloading pyasn1-0.5.0-py2.py3-none-any.whl (83 kB)
#      |████████████████████████████████| 83 kB 9.2 MB/s  eta 0:00:01
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.1.0-cp39-cp39-macosx_11_0_arm64.whl (122 kB)
#      |████████████████████████████████| 122 kB 20.0 MB/s eta 0:00:01
# Collecting idna<4,>=2.5
#   Using cached idna-3.4-py3-none-any.whl (61 kB)
# Collecting certifi>=2017.4.17
#   Downloading certifi-2023.5.7-py3-none-any.whl (156 kB)
#      |████████████████████████████████| 156 kB 24.0 MB/s eta 0:00:01
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      |████████████████████████████████| 151 kB 24.7 MB/s eta 0:00:01
# Installing collected packages: pyasn1, urllib3, rsa, pyparsing, pyasn1-modules, protobuf, idna, charset-normalizer, certifi, cachetools, requests, oauthlib, httplib2, googleapis-common-protos, google-auth, uritemplate, requests-oauthlib, google-auth-httplib2, google-api-core, google-auth-oauthlib, google-api-python-client
# Successfully installed cachetools-5.3.1 certifi-2023.5.7 charset-normalizer-3.1.0 google-api-core-2.11.1 google-api-python-client-2.90.0 google-auth-2.21.0 google-auth-httplib2-0.1.0 google-auth-oauthlib-1.0.0 googleapis-common-protos-1.59.1 httplib2-0.22.0 idna-3.4 oauthlib-3.2.2 protobuf-4.23.3 pyasn1-0.5.0 pyasn1-modules-0.3.0 pyparsing-3.1.0 requests-2.31.0 requests-oauthlib-1.3.1 rsa-4.9 uritemplate-4.1.1 urllib3-1.26.16
# WARNING: You are using pip version 21.2.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Collecting gspread
#   Downloading gspread-5.9.0-py3-none-any.whl (40 kB)
#      |████████████████████████████████| 40 kB 23 kB/s  eta 0:00:01
# Collecting oauth2client
#   Downloading oauth2client-4.1.3-py2.py3-none-any.whl (98 kB)
#      |████████████████████████████████| 98 kB 4.9 MB/s eta 0:00:011
# Requirement already satisfied: google-auth>=1.12.0 in /Users/l.rush/Library/Python/3.9/lib/python/site-packages (from gspread) (2.21.0)
# Requirement already satisfied: google-auth-oauthlib>=0.4.1 in /Users/l.rush/Library/Python/3.9/lib/python/site-packages (from gspread) (1.0.0)
# Requirement already satisfied: httplib2>=0.9.1 in /Users/l.rush/Library/Python/3.9/lib/python/site-packages (from oauth2client) (0.22.0)
# Requirement already satisfied: six>=1.6.1 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from oauth2client) (1.15.0)
# Requirement already satisfied: pyasn1>=0.1.7 in /Users/l.rush/Library/Python/3.9/lib/python/site-packages (from oauth2client) (0.5.0)
# Requirement already satisfied: rsa>=3.1.4 in /Users/l.rush/Library/Python/3.9/lib/python/site-packages (from oauth2client) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /Users/l.rush/Library/Python/3.9/lib/python/site-packages (from oauth2client) (0.3.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/l.rush/Library/Python/3.9/lib/python/site-packages (from google-auth>=1.12.0->gspread) (5.3.1)
# Requirement already satisfied: urllib3<2.0 in /Users/l.rush/Library/Python/3.9/lib/python/site-packages (from google-auth>=1.12.0->gspread) (1.26.16)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/l.rush/Library/Python/3.9/lib/python/site-packages (from google-auth-oauthlib>=0.4.1->gspread) (1.3.1)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /Users/l.rush/Library/Python/3.9/lib/python/site-packages (from httplib2>=0.9.1->oauth2client) (3.1.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/l.rush/Library/Python/3.9/lib/python/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.2.2)
# Requirement already satisfied: requests>=2.0.0 in /Users/l.rush/Library/Python/3.9/lib/python/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/l.rush/Library/Python/3.9/lib/python/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/l.rush/Library/Python/3.9/lib/python/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2023.5.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/l.rush/Library/Python/3.9/lib/python/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.4)
# Installing collected packages: oauth2client, gspread
# Successfully installed gspread-5.9.0 oauth2client-4.1.3
# WARNING: You are using pip version 21.2.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: requests in /Users/l.rush/Library/Python/3.9/lib/python/site-packages (2.31.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/l.rush/Library/Python/3.9/lib/python/site-packages (from requests) (1.26.16)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/l.rush/Library/Python/3.9/lib/python/site-packages (from requests) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/l.rush/Library/Python/3.9/lib/python/site-packages (from requests) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/l.rush/Library/Python/3.9/lib/python/site-packages (from requests) (2023.5.7)
# WARNING: You are using pip version 21.2.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Collecting langchain
#   Downloading langchain-0.0.217-py3-none-any.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 3.4 MB/s eta 0:00:01
# Requirement already satisfied: numpy<2,>=1 in /Users/l.rush/Library/Python/3.9/lib/python/site-packages (from langchain) (1.25.0)
# Collecting openapi-schema-pydantic<2.0,>=1.2
#   Downloading openapi_schema_pydantic-1.2.4-py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 12.5 MB/s eta 0:00:01
# Collecting tenacity<9.0.0,>=8.1.0
#   Downloading tenacity-8.2.2-py3-none-any.whl (24 kB)
# Collecting PyYAML>=5.4.1
#   Downloading PyYAML-6.0-cp39-cp39-macosx_11_0_arm64.whl (173 kB)
#      |████████████████████████████████| 173 kB 17.4 MB/s eta 0:00:01
# Collecting aiohttp<4.0.0,>=3.8.3
#   Downloading aiohttp-3.8.4-cp39-cp39-macosx_11_0_arm64.whl (338 kB)
#      |████████████████████████████████| 338 kB 20.1 MB/s eta 0:00:01
# Collecting dataclasses-json<0.6.0,>=0.5.7
#   Downloading dataclasses_json-0.5.8-py3-none-any.whl (26 kB)
# Collecting pydantic<2,>=1
#   Downloading pydantic-1.10.9-cp39-cp39-macosx_11_0_arm64.whl (2.6 MB)
#      |████████████████████████████████| 2.6 MB 19.7 MB/s eta 0:00:01
# Collecting langchainplus-sdk>=0.0.17
#   Downloading langchainplus_sdk-0.0.17-py3-none-any.whl (25 kB)
# Requirement already satisfied: requests<3,>=2 in /Users/l.rush/Library/Python/3.9/lib/python/site-packages (from langchain) (2.31.0)
# Collecting async-timeout<5.0.0,>=4.0.0
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting numexpr<3.0.0,>=2.8.4
#   Downloading numexpr-2.8.4-cp39-cp39-macosx_11_0_arm64.whl (89 kB)
#      |████████████████████████████████| 89 kB 14.1 MB/s eta 0:00:01
# Collecting SQLAlchemy<3,>=1.4
#   Downloading SQLAlchemy-2.0.17-cp39-cp39-macosx_11_0_arm64.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 23.5 MB/s eta 0:00:01
# Collecting attrs>=17.3.0
#   Using cached attrs-23.1.0-py3-none-any.whl (61 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp39-cp39-macosx_11_0_arm64.whl (29 kB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.9.2-cp39-cp39-macosx_11_0_arm64.whl (62 kB)
#      |████████████████████████████████| 62 kB 6.3 MB/s  eta 0:00:01
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /Users/l.rush/Library/Python/3.9/lib/python/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (3.1.0)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp39-cp39-macosx_11_0_arm64.whl (35 kB)
# Collecting marshmallow<4.0.0,>=3.3.0
#   Downloading marshmallow-3.19.0-py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 11.8 MB/s eta 0:00:01
# Collecting marshmallow-enum<2.0.0,>=1.5.1
#   Downloading marshmallow_enum-1.5.1-py2.py3-none-any.whl (4.2 kB)
# Collecting typing-inspect>=0.4.0
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Requirement already satisfied: packaging>=17.0 in /Users/l.rush/Library/Python/3.9/lib/python/site-packages (from marshmallow<4.0.0,>=3.3.0->dataclasses-json<0.6.0,>=0.5.7->langchain) (23.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/l.rush/Library/Python/3.9/lib/python/site-packages (from pydantic<2,>=1->langchain) (4.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/l.rush/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2->langchain) (2023.5.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/l.rush/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2->langchain) (1.26.16)
# Requirement already satisfied: idna<4,>=2.5 in /Users/l.rush/Library/Python/3.9/lib/python/site-packages (from requests<3,>=2->langchain) (3.4)
# Collecting mypy-extensions>=0.3.0
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: mypy-extensions, multidict, marshmallow, frozenlist, yarl, typing-inspect, tenacity, pydantic, marshmallow-enum, attrs, async-timeout, aiosignal, SQLAlchemy, PyYAML, openapi-schema-pydantic, numexpr, langchainplus-sdk, dataclasses-json, aiohttp, langchain
# Successfully installed PyYAML-6.0 SQLAlchemy-2.0.17 aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 attrs-23.1.0 dataclasses-json-0.5.8 frozenlist-1.3.3 langchain-0.0.217 langchainplus-sdk-0.0.17 marshmallow-3.19.0 marshmallow-enum-1.5.1 multidict-6.0.4 mypy-extensions-1.0.0 numexpr-2.8.4 openapi-schema-pydantic-1.2.4 pydantic-1.10.9 tenacity-8.2.2 typing-inspect-0.9.0 yarl-1.9.2
# WARNING: You are using pip version 21.2.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Collecting openai
#   Downloading openai-0.27.8-py3-none-any.whl (73 kB)
#      |████████████████████████████████| 73 kB 1.9 MB/s eta 0:00:01
# Requirement already satisfied: requests>=2.20 in /Users/l.rush/Library/Python/3.9/lib/python/site-packages (from openai) (2.31.0)
# Requirement already satisfied: aiohttp in /Users/l.rush/Library/Python/3.9/lib/python/site-packages (from openai) (3.8.4)
# Collecting tqdm
#   Using cached tqdm-4.65.0-py3-none-any.whl (77 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/l.rush/Library/Python/3.9/lib/python/site-packages (from requests>=2.20->openai) (3.1.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/l.rush/Library/Python/3.9/lib/python/site-packages (from requests>=2.20->openai) (1.26.16)
# Requirement already satisfied: idna<4,>=2.5 in /Users/l.rush/Library/Python/3.9/lib/python/site-packages (from requests>=2.20->openai) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/l.rush/Library/Python/3.9/lib/python/site-packages (from requests>=2.20->openai) (2023.5.7)
# Requirement already satisfied: attrs>=17.3.0 in /Users/l.rush/Library/Python/3.9/lib/python/site-packages (from aiohttp->openai) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/l.rush/Library/Python/3.9/lib/python/site-packages (from aiohttp->openai) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Users/l.rush/Library/Python/3.9/lib/python/site-packages (from aiohttp->openai) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/l.rush/Library/Python/3.9/lib/python/site-packages (from aiohttp->openai) (1.9.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/l.rush/Library/Python/3.9/lib/python/site-packages (from aiohttp->openai) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/l.rush/Library/Python/3.9/lib/python/site-packages (from aiohttp->openai) (1.3.3)
# Installing collected packages: tqdm, openai
# Successfully installed openai-0.27.8 tqdm-4.65.0
# WARNING: You are using pip version 21.2.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: gspread in /Users/l.rush/Library/Python/3.9/lib/python/site-packages (5.9.0)
# Requirement already satisfied: oauth2client in /Users/l.rush/Library/Python/3.9/lib/python/site-packages (4.1.3)
# Requirement already satisfied: google-auth in /Users/l.rush/Library/Python/3.9/lib/python/site-packages (2.21.0)
# Requirement already satisfied: google-auth-oauthlib in /Users/l.rush/Library/Python/3.9/lib/python/site-packages (1.0.0)
# Requirement already satisfied: google-auth-httplib2 in /Users/l.rush/Library/Python/3.9/lib/python/site-packages (0.1.0)
# Requirement already satisfied: google-api-python-client in /Users/l.rush/Library/Python/3.9/lib/python/site-packages (2.90.0)
# Requirement already satisfied: pyasn1>=0.1.7 in /Users/l.rush/Library/Python/3.9/lib/python/site-packages (from oauth2client) (0.5.0)
# Requirement already satisfied: pyasn1-modules>=0.0.5 in /Users/l.rush/Library/Python/3.9/lib/python/site-packages (from oauth2client) (0.3.0)
# Requirement already satisfied: six>=1.6.1 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from oauth2client) (1.15.0)
# Requirement already satisfied: rsa>=3.1.4 in /Users/l.rush/Library/Python/3.9/lib/python/site-packages (from oauth2client) (4.9)
# Requirement already satisfied: httplib2>=0.9.1 in /Users/l.rush/Library/Python/3.9/lib/python/site-packages (from oauth2client) (0.22.0)
# Requirement already satisfied: urllib3<2.0 in /Users/l.rush/Library/Python/3.9/lib/python/site-packages (from google-auth) (1.26.16)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/l.rush/Library/Python/3.9/lib/python/site-packages (from google-auth) (5.3.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/l.rush/Library/Python/3.9/lib/python/site-packages (from google-auth-oauthlib) (1.3.1)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /Users/l.rush/Library/Python/3.9/lib/python/site-packages (from google-api-python-client) (4.1.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5 in /Users/l.rush/Library/Python/3.9/lib/python/site-packages (from google-api-python-client) (2.11.1)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /Users/l.rush/Library/Python/3.9/lib/python/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (1.59.1)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 in /Users/l.rush/Library/Python/3.9/lib/python/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (4.23.3)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /Users/l.rush/Library/Python/3.9/lib/python/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2.31.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /Users/l.rush/Library/Python/3.9/lib/python/site-packages (from httplib2>=0.9.1->oauth2client) (3.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/l.rush/Library/Python/3.9/lib/python/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (2023.5.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/l.rush/Library/Python/3.9/lib/python/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/l.rush/Library/Python/3.9/lib/python/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0.dev0,>=1.31.5->google-api-python-client) (3.1.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/l.rush/Library/Python/3.9/lib/python/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib) (3.2.2)
# WARNING: You are using pip version 21.2.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Defaulting to user installation because normal site-packages is not writeable
# Collecting python-dotenv
#   Downloading python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.0.0
# WARNING: You are using pip version 21.2.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
# for the predictions
import os
import sys
import sqlite3
import pathlib
import pandas as pd

# for AI Reg Regan
from langchain.llms import OpenAI
import openai

# for Google things
from dotenv import load_dotenv
import base64
from google.oauth2.credentials import Credentials
from google_auth_oauthlib.flow import InstalledAppFlow
from google.auth.transport.requests import Request
from googleapiclient.discovery import build
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
import gspread
from oauth2client.service_account import ServiceAccountCredentials

sys.path.append("use-predictions") 
import save_predictions as sp

# Get to the root directory
project_root = pathlib.Path().absolute().parent.parent

# Now construct the relative path to your SQLite database
db_path = project_root / "data" / "footy-tipper-db.sqlite"
secrets_path = project_root / "secrets.env"

# lead secrets
load_dotenv(dotenv_path=secrets_path)
# Out:
# True

# %%
# Connect to the SQLite database
con = sqlite3.connect(str(db_path))

# Query to select all records from the predictions_table
query = """
    WITH min_round_id AS (
        SELECT MIN(round_id) AS round_id
        FROM footy_tipping_data
        WHERE game_state_name = 'Pre Game'
    )

    SELECT ft.game_id
        , p.home_team_result
        , ft.team_home
        , ft.position_home
        , ft.team_head_to_head_odds_home
        , ft.team_away
        , ft.position_away
        , ft.team_head_to_head_odds_away
        , p.home_team_win_prob
        , p.home_team_lose_prob
        , ft.home_elo
        , ft.away_elo
        , ft.round_id
        , ft.competition_year
        , ft.round_name
    FROM predictions_table p
    LEFT JOIN footy_tipping_data ft ON p.game_id = ft.game_id
    WHERE ft.game_state_name = 'Pre Game'
    AND round_id = (SELECT * FROM min_round_id)
"""

# Execute the query and fetch the results into a data frame
predictions = pd.read_sql_query(query, con)

# Disconnect from the SQLite database
con.close()

# Get prod_run from environment variable. Convert it to boolean.
prod_run = os.getenv('PROD_RUN', 'False') == 'True'

sp.save_predictions(predictions, prod_run=prod_run)
tipper_picks = sp.tipper_picks(predictions, prod_run=prod_run)

predictions
# Out:
#         game_id home_team_result                     team_home  position_home  \
# 0  2.023111e+10             Loss  St. George Illawarra Dragons           15.0
# 1  2.023111e+10             Loss                      Dolphins           10.0
# 2  2.023111e+10              Win              Penrith Panthers            2.0
# 3  2.023111e+10              Win               Melbourne Storm            3.0
# 4  2.023111e+10              Win              Brisbane Broncos            1.0
# 5  2.023111e+10              Win        South Sydney Rabbitohs            4.0
# 6  2.023111e+10              Win               Sydney Roosters           11.0
#
#    team_head_to_head_odds_home                   team_away  position_away  \
# 0                         2.75        New Zealand Warriors            6.0
# 1                         2.75             Parramatta Eels            8.0
# 2                         1.55           Newcastle Knights           14.0
# 3                         1.20  Manly-Warringah Sea Eagles           12.0
# 4                         1.35           Gold Coast Titans            9.0
# 5                         1.45    North Queensland Cowboys           13.0
# 6                         1.60            Canberra Raiders            7.0
#
#    team_head_to_head_odds_away  home_team_win_prob  home_team_lose_prob  \
# 0                         1.45            0.435300             0.564700
# 1                         1.45            0.393582             0.606418
# 2                         2.45            0.591117             0.408883
# 3                         4.50            0.627509             0.372491
# 4                         3.25            0.626871             0.373129
# 5                         2.75            0.595493             0.404507
# 6                         2.35            0.554381             0.445619
#
#       home_elo     away_elo  round_id  competition_year round_name  \
# 0  1486.458681  1509.067023      17.0            2023.0   Round 17
# 1  1477.222338  1538.373525      17.0            2023.0   Round 17
# 2  1543.327663  1487.508067      17.0            2023.0   Round 17
# 3  1529.594162  1494.579544      17.0            2023.0   Round 17
# 4  1517.723248  1485.104398      17.0            2023.0   Round 17
# 5  1524.943235  1498.624605      17.0            2023.0   Round 17
# 6  1481.271216  1484.287857      17.0            2023.0   Round 17
#
#    home_odds_thresh  away_odds_thresh
# 0          2.297266          1.770852
# 1          2.540769          1.649027
# 2          1.691713          2.445687
# 3          1.593604          2.684625
# 4          1.595224          2.680041
# 5          1.679280          2.472146
# 6          1.803815          2.244067

# %% [markdown]
# # Langchain

# %%
llm = OpenAI(openai_api_key=os.getenv('OPENAI_KEY'),
             model_name="gpt-3.5-turbo-16k",
             max_tokens=15000,
             temperature=1.1)

input_predictions = ""

for index, row in predictions.iterrows():
    input_predictions += f"""

        Round Name: {row['round_name']},
        Home Team Result: {row['home_team_result']},
        Home Team: {row['team_home']}, 
        Home Team Position: {row['position_home']},
        Home Team Head to Head Price: {row['team_head_to_head_odds_home']}
        Away Team: {row['team_away']},
        Away Team Position: {row['position_away']},
        Away Team Head to Head Price: {row['team_head_to_head_odds_away']}\n

        """
    
prompt = f"""

    I have a set of predictions for NRL games in {predictions['round_name'].unique()[0]} {predictions['competition_year'].unique()[0]} made by a machine learning pipeline called the Footy Tipper: \n{input_predictions}\n 

    The description of the columns of interest is:

    * Home Team Result: the predicted result of the home team
    * Home Team: the home team
    * Home Team Position: the home team's position on the NRL ladder
    * Home Team Head to Head Price: the price bookies are offering for a home win
    * Away Team: the away team
    * Away Team Position: the away team's position on the NRL ladder
    * Away Team Head to Head Price: the price bookies are offering for an away win

    Could you write up an email to my mates from Reg Regan, giving them a synopsis of the round along withthe tips? 
    Accompany the tips with some smart arsed comments to about the teams playing.
    
    Remember to link everyone to the tips folder: https://drive.google.com/drive/folders/1lT1SQH-kQPdnOf3ftomobuiv51jEj6t-?usp=sharing
    Also, tell everyone to bring back the biff at the end of the email.

    Always sign off the email as Reg Regan.
    
    """

reg_regan = llm.predict(prompt)

print(reg_regan)
# Out:
# Dear mates,
#
# Hope you're all doing well. I wanted to give you a heads up on the upcoming NRL Round 17 games and share some predictions made by a nifty machine learning pipeline called the Footy Tipper. As always, here's the link to the tip folder for your reference: [NRL Round 17 Tips](https://drive.google.com/drive/folders/1lT1SQH-kQPdnOf3ftomobuiv51jEj6t-?usp=sharing).
#
# Let's dive into the predictions and add a touch of smart arsed commentary for good measure:
#
# 1. St. George Illawarra Dragons vs New Zealand Warriors: The Footy Tipper foresees a loss for the Dragons. When you have mischievous Warriors on the field, dragons tend to get roasted. Keep the fire extinguisher nearby.
#
# 2. Dolphins vs Parramatta Eels: The Dolphins are predicted to lose in this match. Looks like the Eels are in no mood to play nice-nice with the newbies. Swimming lessons might be needed after this game.
#
# 3. Penrith Panthers vs Newcastle Knights: The mighty Penrith Panthers are expected to triumph. Even knights in shining armor bow down to their feline adversaries. Who needs a sword when you have claws?
#
# 4. Melbourne Storm vs Manly-Warringah Sea Eagles: The Footy Tipper envisions another victory for the Storm. The Sea Eagles might want to rethink their game plan because Stormy weather is headed their way. Better bring an umbrella.
#
# 5. Brisbane Broncos vs Gold Coast Titans: It's time for the Broncos to shine as they are predicted to secure a win. The Titans better be prepared for the beastly Broncos to put on a show. Buckle up, boys.
#
# 6. South Sydney Rabbitohs vs North Queensland Cowboys: The Rabbitohs hop into this game with a predicted win. Cowboys may be tough, but rabbits are quick on their feet. The race is on!
#
# 7. Sydney Roosters vs Canberra Raiders: The Roosters are anticipated to celebrate a victory. It's time for the Roosters to gather and protect their turf from the Raiders. Who will rule the roost?
#
# And there you have it, the predictions for NRL Round 17 according to our trusty Footy Tipper. Remember, these predictions are just for fun and banter among mates.
#
# Now, onto the important matter of bringing back the biff. Let's light up the passion and intensity of the game by encouraging a bit of biff like the good ol' days. It's time to add a dash of spice to the NRL battles and remind everyone of the fierce rivalry we all love.
#
# Stay tuned for more thrilling NRL action and may the best team win!
#
# Yours sincerely,
#
# Reg Regan

# %% [markdown]
# # send emails

# %%
project_root = pathlib.Path().absolute().parent.parent
json_path = project_root / "footy-tipper-c5bcb9639ee2.json"

# Use your downloaded credentials file
scope = ["https://spreadsheets.google.com/feeds", 'https://www.googleapis.com/auth/spreadsheets',
         "https://www.googleapis.com/auth/drive.file", "https://www.googleapis.com/auth/drive"]

creds = ServiceAccountCredentials.from_json_keyfile_name(json_path, scope)
client = gspread.authorize(creds)

# Open the test sheet and get the data
sheet = client.open("footy-tipper-email-list").sheet1  # use your actual sheet name
email_data = sheet.get_all_records()  # gets all the data inside your Google Sheet

your_mates_emails = [row['Email'] for row in email_data]  # replace 'Email' with your actual column name

# %%
# Setup the email
msg = MIMEMultipart()
msg['From'] = os.getenv('MY_EMAIL')
msg['To'] = ', '.join(your_mates_emails)
msg['Subject'] = f"Footy Tipper Predictions for {predictions['round_name'].unique()[0]}"

# Add your message
message = reg_regan  # or whatever variable has your final message
msg.attach(MIMEText(message, 'plain'))

# Setup the SMTP server
server = smtplib.SMTP('smtp.gmail.com', 587)
server.starttls()

# Add your credentials
server.login(os.getenv('MY_EMAIL'), os.getenv('EMAIL_PASSWORD'))

# Send the email
text = msg.as_string()
server.sendmail(os.getenv('MY_EMAIL'), your_mates_emails, text)

# Close the connection
server.quit()
# Out:
# (221,
#  b'2.0.0 closing connection p38-20020a634f66000000b005535ddd8dcfsm5431199pgl.89 - gsmtp')
